# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("club.csv")

# %%
df.sample(10)
# Out:
#                 Club Name Competition Name  Squad Size  \
# 41         ACF Fiorentina          Serie A          26
# 16             RB Leipzig       Bundesliga          29
# 74          Fenerbahce SK        Süper Lig          32
# 56       Shakhtar Donetsk     Premier Liga          29
# 31               SS Lazio          Serie A          33
# 55              Torino FC          Serie A          30
# 15             SSC Napoli          Serie A          26
# 6             Real Madrid           LaLiga          27
# 94  FC Girondins Bordeaux          Ligue 1          30
# 42    Olympique Marseille          Ligue 1          27
#
#     Average Age Of Players  Market Value Of Club In Millions(£)  \
# 41                    27.0                               228.42
# 16                    24.1                               447.80
# 74                    25.5                               114.17
# 56                    25.8                               165.60
# ...
