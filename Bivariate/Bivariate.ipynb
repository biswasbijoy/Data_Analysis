# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
df.sample(10)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 175         176  Female   30                  88                      86
# 6             7  Female   35                  18                       6
# 192         193    Male   33                 113                       8
# 0             1    Male   19                  15                      39
# 36           37  Female   42                  34                      17
# 102         103    Male   67                  62                      59
# 11           12  Female   35                  19                      99
# 108         109    Male   68                  63                      43
# 149         150    Male   34                  78                      90
# 50           51  Female   49                  42                      52

# %%
sns.barplot(df['Annual Income (k$)'], df['Age'], hue = df['Genre'])
# Out:
# C:\Users\Bijoy\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Age'>

# %%
sns.heatmap(pd.crosstab(df["Age"], df["Spending Score (1-100)"]))
# Out:
# <AxesSubplot:xlabel='Spending Score (1-100)', ylabel='Age'>

# %%
sns.pairplot(df, hue = "Age")
